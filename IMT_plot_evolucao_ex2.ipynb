# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroMatumoto/data-visualization-notebooks/blob/main/IMT_plot_evolucao_ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from datetime import datetime
corona_Brasil = pd.read_csv('https://raw.githubusercontent.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/main/data/corona_Brasil.csv')
corona_Brasil.data = pd.to_datetime(corona_Brasil.data, format='%Y-%m-%d',errors='coerce')

bovespa = pd.read_csv('https://raw.githubusercontent.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/main/data/mystocksn.csv')
bovespa.data = pd.to_datetime(bovespa.data, format='%Y-%m-%d',errors='coerce') # somente para ajustar formato da datas

display(corona_Brasil.head())
display(bovespa.head())

# definir data como índice
# Out:
#    regiao  estado  municipio  coduf  codmun  codRegiaoSaude  nomeRegiaoSaude  \
# 0  Brasil     NaN        NaN     76     NaN             NaN              NaN
# 1  Brasil     NaN        NaN     76     NaN             NaN              NaN
# 2  Brasil     NaN        NaN     76     NaN             NaN              NaN
# 3  Brasil     NaN        NaN     76     NaN             NaN              NaN
# 4  Brasil     NaN        NaN     76     NaN             NaN              NaN
#
#         data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0 2020-02-25        9.0       210147125.0             0.0         0.0
# 1 2020-02-26        9.0       210147125.0             1.0         1.0
# 2 2020-02-27        9.0       210147125.0             1.0         0.0
# 3 2020-02-28        9.0       210147125.0             1.0         0.0
# 4 2020-02-29        9.0       210147125.0             2.0         1.0
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %% [markdown]
# # Exercício 1
#
# Faça um gráfico o mais similar possível do gráfico abaixo.

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(corona_Brasil.data, corona_Brasil.casosNovos, label='Novos Casos', color='blue')
ax2 = ax.twinx()
ax2.plot(bovespa.data, bovespa.DOLAR, label='DOLAR', color='r')
ax.set_xlabel('date')
ax.set_ylabel('Novos Casos')
ax2.set_ylabel('USD')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Exercício 2
#
# Faça um gráfico o mais similar possível do gráfico abaixo.
#
# Dicas:
#
# 1. Para a correlação faça o join dos dados por data.
# 2. Empregue:
# ```
# bovespa.DOLAR.rolling(30).mean()
# corona_Brasil.casosNovos.rolling(30).mean()
# ```
# Para gerar as séries médias.

# %% [markdown]
# Faça antes, para o ajuste do `rolling()`

# %%
corona_Brasil = corona_Brasil.set_index('data')
bovespa = bovespa.set_index('data')

# %%
merged_df = pd.merge(corona_Brasil, bovespa, on='data')
merged_df.head()
# Out:
#             regiao  estado  municipio  coduf  codmun  codRegiaoSaude  \
# data
# 2020-02-27  Brasil     NaN        NaN     76     NaN             NaN
# 2020-02-28  Brasil     NaN        NaN     76     NaN             NaN
# 2020-03-02  Brasil     NaN        NaN     76     NaN             NaN
# 2020-03-03  Brasil     NaN        NaN     76     NaN             NaN
# 2020-03-04  Brasil     NaN        NaN     76     NaN             NaN
#
#             nomeRegiaoSaude  semanaEpi  populacaoTCU2019  casosAcumulado  \
# data
# 2020-02-27              NaN        9.0       210147125.0             1.0
# 2020-02-28              NaN        9.0       210147125.0             1.0
# 2020-03-02              NaN       10.0       210147125.0             2.0
# 2020-03-03              NaN       10.0       210147125.0             2.0
# 2020-03-04              NaN       10.0       210147125.0             3.0
#
#             casosNovos  obitosAcumulado  obitosNovos  Recuperadosnovos  \
# data
# ...

# %%
fig, ax = plt.subplots(figsize=(14, 6))
ax.plot(merged_df.index, merged_df.casosNovos, label='Novos Casos', color='blue',alpha=0.3)
ax2 = ax.twinx()
ax2.plot(merged_df.index, merged_df.DOLAR, label='DOLAR', color='darkred',alpha=0.3)
ax.set_xlabel('date')
ax.set_ylabel('Novos Casos')
ax2.set_ylabel('USD')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
ax.plot(merged_df.index, merged_df.casosNovos.rolling(30).mean(), label='Novos Casos Média', color='blue')
ax2.plot(merged_df.index, merged_df.DOLAR.rolling(30).mean(), label='DOLAR Média', color='darkred')
# fazer corr
corr = merged_df.casosNovos.corr(merged_df.DOLAR)
print(corr)
# annotate
ax.text(0.4, 0.8, f'Correlation = {corr:.2f}', transform=ax.transAxes, fontsize=20, color='darkred')
# ax.title('Novos Casos de Covid x USD (Brasil)')
plt.show()
# Out:
# 0.1558215584988902
